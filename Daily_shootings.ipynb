# %% [markdown]
# ## Daily U.S. Gun Violence incidents
#
# Gun Violence Archive puts together a great list of gun violence incidents everyday, putting it together from over 7,200 sources.
# The below code is to display how many incidents and injuries/deaths happened TODAY.
#
# We are going to scrape https://www.gunviolencearchive.org/last-72-hours
# for daily gun violence stats

# %%
import pandas as pd
from selenium import webdriver
from bs4 import BeautifulSoup
import requests
import re

# %%
from datetime import date

today = date.today()

# Textual month, day and year	
datenow = today.strftime("%B %-d, %Y")

#Adding a hyphen b/w % and 'd' removes 0!
datenow
# Out:
# 'January 8, 2021'

# %%
url = "https://www.gunviolencearchive.org/last-72-hours"
response = requests.get(url)
doc = BeautifulSoup(response.text)

# %%
shootings_table = pd.read_html(response.text)[0]
shootings_table
# Out:
#       Incident Date       State          City Or County  \
# 0   January 7, 2021     Florida            Jacksonville
# 1   January 7, 2021     Florida                   Miami
# 2   January 7, 2021    Illinois                 Chicago
# 3   January 7, 2021    Kentucky              Louisville
# 4   January 7, 2021    Illinois                 Chicago
# 5   January 7, 2021    Kentucky              Louisville
# 6   January 7, 2021    Kentucky              Louisville
# 7   January 7, 2021    Kentucky               Lexington
# 8   January 7, 2021    New York                   Bronx
# 9   January 7, 2021     Alabama              Huntsville
# 10  January 7, 2021    Michigan                 Detroit
# 11  January 7, 2021   Minnesota                 Newport
# 12  January 7, 2021  California           San Francisco
# 13  January 7, 2021       Texas                Marshall
# 14  January 7, 2021  California                Hesperia
# 15  January 7, 2021       Texas                 Houston
# ...

# %%
# Converting following columns to integers from str

today_df['killed'] = today_df['killed'].astype(int)
today_df['injured'] = today_df['injured'].astype(int)

# %%
print(f"So far today, on {today_df['date'][0]}, {today_df['killed'].sum()} people have died as a result of gun violence, and {today_df['injured'].sum()} have been injured.")
# Out:
# So far today, on January 6, 2021, 0 people have died as a result of gun violence, and 4 have been injured.
